# %% [markdown]
# <a href="https://colab.research.google.com/github/zbigsr814/data-scienice-bootcamp/blob/main/08_SQLinPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_raw = pd.read_csv('avocado.csv')
df = df_raw.copy()
df.head(4)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany

# %% [markdown]
# Porównanie do SQL

# %%
df.describe().T

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df['4046'] = df['4046'].apply(lambda x: str(int(x)))
df.head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-465b05046aeb> in <module>
# ----> 1 df['4046'] = df['4046'].apply(lambda x: str(int(x)))
#       2 df.head(1)
#
# NameError: name 'df' is not defined

# %%
df[['Total Bags', 'Small Bags', 'Large Bags']].head(5)
# Out:
#    Total Bags  Small Bags  Large Bags
# 0     8696.87     8603.62       93.25
# 1     9505.56     9408.07       97.49
# 2     8145.35     8042.21      103.14
# 3     5811.16     5677.40      133.76
# 4     6183.95     5986.26      197.69

# %%
df[['Total Bags', 'Small Bags', 'Large Bags']][7:10]
# Out:
#    Total Bags  Small Bags  Large Bags
# 7     6829.22     6266.85      562.37
# 8    11388.36    11104.53      283.83
# 9     8625.92     8061.47      564.45

# %%
df[df['AveragePrice'] == 1.33].count()
# Out:
# Unnamed: 0      159
# Date            159
# AveragePrice    159
# Total Volume    159
# 4046            159
# 4225            159
# 4770            159
# Total Bags      159
# Small Bags      159
# Large Bags      159
# XLarge Bags     159
# type            159
# year            159
# region          159
# dtype: int64

# %%
df[(df['AveragePrice'] == 1.33) & (df['Total Volume'] > 54454)].head()
# Out:
#      Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 0             0  2015-12-27          1.33      64236.62  1036.74  54454.85
# 14           14  2015-09-20          1.33      69759.01  1028.03  59313.12
# 19           19  2015-08-16          1.33      80043.78   539.65  68666.01
# 272          12  2015-10-04          1.33      98900.48  3020.03  38353.35
# 293          33  2015-05-10          1.33     170547.18  1321.83  73754.30
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0     48.16     8696.87     8603.62       93.25          0.0  conventional
# 14   150.50     9267.36     8489.10      778.26          0.0  conventional
# 19   394.90    10443.22    10297.68      145.54          0.0  conventional
# 272  101.43    57425.67    56141.23     1284.44          0.0  conventional
# 293  185.16    95285.89    94832.56      453.33          0.0  conventional
#
#      year            region
# 0    2015            Albany
# ...

# %% [markdown]
# not null walue

# %%
df[df['region'].notnull()].head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.groupby('region').size()

# %%
df['WithoutXLarge'] = df['Small Bags'] + df['Large Bags']
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  WithoutXLarge
# 0  2015  Albany        8696.87
# ...

# %%
df.groupby('Unnamed: 0').aggregate({'Small Bags': np.mean}).head()
# Out:
#                Small Bags
# Unnamed: 0
# 0           216944.095208
# 1           200312.278264
# 2           208510.072616
# 3           205426.332894
# 4           183355.315972

# %%
df.nsmallest(n=5, columns='XLarge Bags')
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  WithoutXLarge
# 0  2015  Albany        8696.87
# ...
